# %%
# libraries
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from unum import Unum
# data
from data.data import *

# setup
sns.set_theme(style="whitegrid", palette="Set2")
# sns.set_theme(style="ticks", palette="Set2")

# %%
# Read the data
raw_data: pd.DataFrame = data.parse_data('../reports/base.txt')
df_base: pd.DataFrame = raw_data.loc[raw_data.name == 'matrix transpose base' ].copy()
print(df_base)
# Out:
#                     name          time  space
# 0  matrix transpose base  3.118460e-08     16
# 1  matrix transpose base  5.710930e-08     64
# 2  matrix transpose base  1.507110e-07    256
# 3  matrix transpose base  4.941820e-07   1024
# 4  matrix transpose base  1.724950e-06   4096
# 5  matrix transpose base  1.742800e-06   4096
# 6  matrix transpose base  6.893470e-06  16384
# 7  matrix transpose base  1.063490e-05  25600
# 8  matrix transpose base  1.607840e-05  40000

# %%
sns.regplot(  # linear Regression
    data=df_base, label="matrix transpose base",
    x="space", y="time",
    order=1, ci=None
)
plt.title('Time over input size')
# Whould I be using a logarictimic scale because the value range is large?
# plt.yscale('log')
# plt.xscale('log')
plt.xlabel('Input Size (bytes)')
plt.ylabel('Time (s)')
plt.legend()
plt.show()
